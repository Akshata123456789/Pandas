# %% [markdown]
# <a href="https://colab.research.google.com/github/akshata-data/Pandas/blob/main/class7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv("/content/train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 11. What is Univariate Analysis?
# How Many People Survived And How Many Died?
# How Many Passengers Were In First Class, Second Class, and Third Class?
# Number of Male And Female Passengers

# %% [markdown]
# ans: analysing single variabl or single column at a time to undestand characteristics and distribution of values

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df["Survived"])

plt.xticks([0,1],["Died","Survived"])
plt.xlabel("Survived Column")
plt.title("Survived vs Died")
plt.show()

# %%
sns.boxplot(df["Survived"])
# Out:
# <Axes: ylabel='Survived'>

# %%
sns.kdeplot(df["Survived"])
# Out:
# <Axes: xlabel='Survived', ylabel='Density'>

# %% [markdown]
# ***  above boxplot is not suitable because, survived column contains binary values i.e 1 or 0 but boxplot is use for summarize the distribution of values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.histplot(df["Pclass"])
plt.xticks([1,2,3],["First_cls","Second_cls","Third_cls"])
plt.xlabel("Passenger Class")
plt.title("Passenger class details")
plt.show()

# %%
sns.kdeplot(df["Pclass"])
# Out:
# <Axes: xlabel='Pclass', ylabel='Density'>

# %%
sns.countplot(df["Sex"])
plt.title("Gender details")
plt.show()

# %%
sns.barplot(df["Sex"])
# Out:
# <Axes: ylabel='Sex'>

# %% [markdown]
# 12. Bivariate Analysis
# How Has Better Chance of Survival Male or Female?
# Which Passenger Class Has Better Chance of Survival (First, Second, Or Third Class)?

# %% [markdown]
# ans: analysing two varient or 2 column together to check the relation between them or how they are related is called bivarient analysis

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.barplot(x="Sex",y="Survived",data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
sns.boxplot(x="Sex",y="Survived",data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
sns.barplot(x="Pclass",y="Survived",data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
sns.boxplot(x="Pclass",y="Survived",data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# 13. Feature Engineering
