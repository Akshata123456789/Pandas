# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshata123456789/Pandas/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dict1 ={'Name':['Priyang','Aadhya','Krisha','Vedant','Parshv',
                'Mittal','Archana'],
                'Marks':[98,89,99,87,90,83,99],
                'Gender':['Male','Female','Female','Male','Male',
                         'Female','Female']
               }

# %%
import pandas as pd
df=pd.DataFrame(dict1)

# %%
df
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
df.head(3)
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female

# %%
df.tail(3)
# Out:
#       Name  Marks  Gender
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
df.shape
# Out:
# (7, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Marks   7 non-null      int64
#  2   Gender  7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 300.0+ bytes

# %%
df.isnull().sum()
# Out:
# Name      0
# Marks     0
# Gender    0
# dtype: int64

# %%
df.describe(include="all")
# Out:
#            Name      Marks  Gender
# count         7   7.000000       7
# unique        7        NaN       2
# top     Priyang        NaN  Female
# freq          1        NaN       4
# mean        NaN  92.142857     NaN
# std         NaN   6.491753     NaN
# min         NaN  83.000000     NaN
# 25%         NaN  88.000000     NaN
# 50%         NaN  90.000000     NaN
# 75%         NaN  98.500000     NaN
# max         NaN  99.000000     NaN

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    4
# Male      3
# Name: count, dtype: int64

# %%
df[df['Marks'].between(90,100)]
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 2   Krisha     99  Female
# 4   Parshv     90    Male
# 6  Archana     99  Female

# %%
sum(df['Marks'].between(90,100))
# Out:
# 4

# %%
df[(df['Marks']>= 90) & (df['Marks']<=100)]
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 2   Krisha     99  Female
# 4   Parshv     90    Male
# 6  Archana     99  Female

# %%
len(df[(df['Marks']>=90) & (df['Marks']<=100)])
# Out:
# 4

# %%
df['Marks'].mean()
# Out:
# np.float64(92.14285714285714)

# %%
df['Marks'].max()
# Out:
# 99

# %%
def m1(x):
  return x/2

# %%
df['half_marks']=df['Marks'].apply(m1)

# %%
df
# Out:
#       Name  Marks  Gender  half_marks
# 0  Priyang     98    Male        49.0
# 1   Aadhya     89  Female        44.5
# 2   Krisha     99  Female        49.5
# 3   Vedant     87    Male        43.5
# 4   Parshv     90    Male        45.0
# 5   Mittal     83  Female        41.5
# 6  Archana     99  Female        49.5

# %%
df['Marks'].apply(lambda x:x/2)
# Out:
# 0    49.0
# 1    44.5
# 2    49.5
# 3    43.5
# 4    45.0
# 5    41.5
# 6    49.5
# Name: Marks, dtype: float64

# %%
df['Male_Female']=df['Gender'].map({'Male':1,'Female':0})

# %%
df
# Out:
#       Name  Marks  Gender  half_marks  Male_Female
# 0  Priyang     98    Male        49.0            1
# 1   Aadhya     89  Female        44.5            0
# 2   Krisha     99  Female        49.5            0
# 3   Vedant     87    Male        43.5            1
# 4   Parshv     90    Male        45.0            1
# 5   Mittal     83  Female        41.5            0
# 6  Archana     99  Female        49.5            0

# %%
df.drop(["Male_Female"],axis=1)
# Out:
#       Name  Marks  Gender  half_marks
# 0  Priyang     98    Male        49.0
# 1   Aadhya     89  Female        44.5
# 2   Krisha     99  Female        49.5
# 3   Vedant     87    Male        43.5
# 4   Parshv     90    Male        45.0
# 5   Mittal     83  Female        41.5
# 6  Archana     99  Female        49.5

# %%
df.drop(["Male_Female","half_marks"],axis=1,inplace=True)

# %%
df
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
df.columns
# Out:
# Index(['Name', 'Marks', 'Gender', 'half_marks', 'Male_Female'], dtype='object')

# %%
df['Marks'].sort_values(ascending=False)
# Out:
# 2    99
# 6    99
# 0    98
# 4    90
# 1    89
# 3    87
# 5    83
# Name: Marks, dtype: int64

# %%
df.sort_values(by=["Marks","Gender"])
# Out:
#       Name  Marks  Gender
# 5   Mittal     83  Female
# 3   Vedant     87    Male
# 1   Aadhya     89  Female
# 4   Parshv     90    Male
# 0  Priyang     98    Male
# 2   Krisha     99  Female
# 6  Archana     99  Female

# %%
# !git clone https://github.com/users/Akshata123456789/projects/4
# Out:
# Cloning into '4'...
# remote: Not Found
# fatal: repository 'https://github.com/users/Akshata123456789/projects/4/' not found
